# %% [markdown]
# <a href="https://colab.research.google.com/github/Iagogarcia28/PA-2026/blob/main/Aula_dia_30_03_1C_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("--------------------CALCULADORA SIMPLES--------------------")
print ("                                                           ")
print ("--------------------------MENU-----------------------------")
print ("                                                           ")
print ("Soma = 1                                                   ")
print ("                                                           ")
print ("Subtração = 2                                              ")
print ("                                                           ")
print ("Multiplicação = 3                                          ")
print ("                                                           ")
print ("Divisão = 4                                                ")
# Out:
# --------------------CALCULADORA SIMPLES--------------------
#
# --------------------------MENU-----------------------------
#
# Soma = 1
#
# Subtração = 2
#
# Multiplicação = 3
#
# Divisão = 4

# %%
# Calculadora Simples em Python

def calculadora():
    print("Selecione a operação:")
    print("1 - Soma")
    print("2 - Subtração")
    print("3 - Multiplicação")
    print("4 - Divisão")

    escolha = input("Digite o número da operação (1/2/3/4): ")

    # Verifica se a opção é válida
    if escolha in ('1', '2', '3', '4'):
        try:
            num1 = float(input("Digite o primeiro número: "))
            num2 = float(input("Digite o segundo número: "))
        except ValueError:
            print("Erro: Entrada inválida. Digite números.")
            return

        if escolha == '1':
            print(f"Resultado: {num1 + num2}")
        elif escolha == '2':
            print(f"Resultado: {num1 - num2}")
        elif escolha == '3':
            print(f"Resultado: {num1 * num2}")
        elif escolha == '4':
            if num2 != 0:
                print(f"Resultado: {num1 / num2}")
            else:
                print("Erro: Divisão por zero não permitida.")
    else:
        print("Opção inválida.")

# Executa a calculadora
calculadora()
# Out:
# Selecione a operação:
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# Digite o número da operação (1/2/3/4): 4
# Digite o primeiro número: 8
# Digite o segundo número: 7
# Resultado: 1.1428571428571428

# %%
nome = str (input("Digite seu nome: "))
idade = int (input("Digite sua idade: "))
if idade < 12:
  print(f"{nome}, você é criança.")
elif idade < 18:
  print(f"{nome}, você é adolescente.")
else:
  print(f"{nome}, você é adulto.")
# Out:
# Digite seu nome: 67
# Digite sua idade: 67
# 67, você é adulto.

# %%
lado1 = int (input("Digite o lado do triângulo: "))
lado2 = int (input("Digite o lado do triângulo: "))
lado3 = int (input("Digite o lado do triângulo: "))
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:
  print(f"O triângulo é válido")
if lado1 == lado2 and lado2 == lado3:
  print("Triângulo equilátero")
elif lado1 == lado2 and lado2 != lado3:
  print("Triângulo isóceles")
else:
  print("Triângulo escaleno")
# Out:
# Digite o lado do triângulo: 5
# Digite o lado do triângulo: 5
# Digite o lado do triângulo: 5
# O triângulo é válido
# Triângulo equilátero
